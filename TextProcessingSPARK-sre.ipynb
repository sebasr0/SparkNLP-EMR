# %% [markdown]
# # Text Processing:
# ---

# %%
import sparknlp

spark = sparknlp.start()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>4</td><td>application_1730817751874_0005</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-37-24.ec2.internal:20888/proxy/application_1730817751874_0005/">Link</a></td><td><a target="_blank" href="http://ip-172-31-34-44.ec2.internal:8042/node/containerlogs/container_1730817751874_0005_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Warning::Spark Session already created, some configs may not take.

# %%
sc._conf.get('spark.executor.memory')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# '7g'

# %% [markdown]
# ## Librerias:

# %%
# PySpark SQL Modules
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import col, lit, when, trim, split, udf, expr
from pyspark.sql.types import StringType, ArrayType
from sparknlp.annotator import *

# PySpark ML Modules
from pyspark.ml import Pipeline, Transformer
from pyspark.ml.feature import Tokenizer, StopWordsRemover

# NLTK Modules
import nltk
from nltk.stem import WordNetLemmatizer

# Other Libraries
import os
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Lectura de Datos
# ---

# %%
# Ruta al archivo JSON
file_path = 's3://bucketspark14/complaints.json'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Cargar archivo JSON en Spark DataFrame
df_tickets = spark.read.json(file_path)

# Desanidar las columnas dentro de _source
df_tickets_flat = df_tickets.select(
    "_id", "_index", "_score",
    col("_source.tags").alias("tags"),
    col("_source.zip_code").alias("zip_code"),
    col("_source.complaint_id").alias("complaint_id"),
    col("_source.issue").alias("issue"),
    col("_source.date_received").alias("date_received"),
    col("_source.state").alias("state"),
    col("_source.consumer_disputed").alias("consumer_disputed"),
    col("_source.product").alias("product"),
    col("_source.company_response").alias("company_response"),
    col("_source.company").alias("company"),
    col("_source.submitted_via").alias("submitted_via"),
    col("_source.date_sent_to_company").alias("date_sent_to_company"),
    col("_source.company_public_response").alias("company_public_response"),
    col("_source.sub_product").alias("sub_product"),
    col("_source.timely").alias("timely"),
    col("_source.complaint_what_happened").alias("complaint_what_happened"),
    col("_source.sub_issue").alias("sub_issue"),
    col("_source.consumer_consent_provided").alias("consumer_consent_provided"),
    "_type"
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Limpieza de Datos
# ---

# %%
# Seleccionar la columnas
df_filtered = df_tickets_flat.select('complaint_what_happened','product','sub_product')

# Concatenar las columnas 'category' y 'sub_category' con un '+' en medio
df_filtered = df_filtered.withColumn('category', F.concat_ws('+', F.col('product'), F.col('sub_product')))

# Eliminar la columna 'sub_category'
df_filtered = df_filtered.drop('product','sub_product')

# Reemplazar cadenas vacías por nulos
df_filtered = df_filtered.withColumn("complaint_what_happened", when(trim(col("complaint_what_happened")) == "", lit(None)).otherwise(col("complaint_what_happened")))        

# Eliminar filas con nulos en columnas especificadas
df_filtered = df_filtered.dropna(subset=["complaint_what_happened", "category"])

df_filtered.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------------+--------------------+
# |complaint_what_happened|            category|
# +-----------------------+--------------------+
# |   Good morning my n...|Debt collection+C...|
# |   I upgraded my XXX...|Credit card or pr...|
# |   Chase Card was re...|Credit reporting,...|
# |   On XX/XX/2018, wh...|Credit reporting,...|
# |   my grand son give...|Checking or savin...|
# |   Can you please re...|Credit reporting,...|
# |   With out notice J...|Checking or savin...|
# |   During the summer...|Vehicle loan or l...|
# |   On XXXX XX/XX/201...|Money transfer, v...|
# |   I have a Chase cr...|Credit card or pr...|
# |   mishandling of th...|Vehicle loan or l...|
# |   I have reached ou...|Credit reporting,...|
# |   I opened an accou...|Checking or savin...|
# |   To whom it may co...|Checking or savin...|
# |   My chase amazon c...|Credit card or pr...|
# |   I opened the savi...|Checking or savin...|
# |   XXXX XXXX a sofa,...|Checking or savin...|
# |   My card went miss...|Checking or savin...|
# |   Chase sent me an ...|Credit card or pr...|
# |   I made a purchase...|Checking or savin...|
# +-----------------------+--------------------+
# only showing top 20 rows

# %%
# Definir una UDF para aplicar todas las transformaciones en Spark
def clean_text_spark(df, text_column):
    # Convertir el texto a minúsculas
    df = df.withColumn(text_column, F.lower(F.col(text_column)))
    
    # Eliminar texto en corchetes []
    df = df.withColumn(text_column, F.regexp_replace(F.col(text_column), r'\[.*?\]', ''))
    
    # Eliminar puntuación
    df = df.withColumn(text_column, F.regexp_replace(F.col(text_column), r'[^\w\s]', ''))
    
    # Eliminar palabras que contienen números
    df = df.withColumn(text_column, F.regexp_replace(F.col(text_column), r'\b\w*\d\w*\b', ''))
    
    # Eliminar espacios en blanco adicionales
    df = df.withColumn(text_column, F.trim(F.col(text_column)))
    
    return df

# Aplicar la función de limpieza
df_cleaned = clean_text_spark(df_filtered, 'complaint_what_happened')

# Mostrar el resultado limpio
df_cleaned.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------------+--------------------+
# |complaint_what_happened|            category|
# +-----------------------+--------------------+
# |   good morning my n...|Debt collection+C...|
# |   i upgraded my xxx...|Credit card or pr...|
# |   chase card was re...|Credit reporting,...|
# |   on  while trying ...|Credit reporting,...|
# |   my grand son give...|Checking or savin...|
# |   can you please re...|Credit reporting,...|
# |   with out notice j...|Checking or savin...|
# |   during the summer...|Vehicle loan or l...|
# |   on xxxx  i made a...|Money transfer, v...|
# |   i have a chase cr...|Credit card or pr...|
# |   mishandling of th...|Vehicle loan or l...|
# |   i have reached ou...|Credit reporting,...|
# |   i opened an accou...|Checking or savin...|
# |   to whom it may co...|Checking or savin...|
# |   my chase amazon c...|Credit card or pr...|
# |   i opened the savi...|Checking or savin...|
# |   xxxx xxxx a sofa ...|Checking or savin...|
# |   my card went miss...|Checking or savin...|
# |   chase sent me an ...|Credit card or pr...|
# |   i made a purchase...|Checking or savin...|
# +-----------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
import re

# Define a UDF to remove "xxxx" and any extra spaces left by the removal
def remove_xxxx(text):
    # Remove "xxxx" and any spaces left behind
    return re.sub(r"\s*xxxx\s*", "", text)

# Register the UDF with Spark
remove_xxxx_udf = udf(remove_xxxx, StringType())

# Apply the UDF to the 'complaint_what_happened' column
df_cleaned = df_cleaned.withColumn("complaint_what_happened", remove_xxxx_udf("complaint_what_happened"))

# Verify the column after cleaning
df_cleaned.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------------+--------------------+
# |complaint_what_happened|            category|
# +-----------------------+--------------------+
# |   good morning my n...|Debt collection+C...|
# |   i upgraded mycard...|Credit card or pr...|
# |   chase card was re...|Credit reporting,...|
# |   on  while trying ...|Credit reporting,...|
# |   my grand son give...|Checking or savin...|
# |   can you please re...|Credit reporting,...|
# |   with out notice j...|Checking or savin...|
# |   during the summer...|Vehicle loan or l...|
# |   oni made a  payme...|Money transfer, v...|
# |   i have a chase cr...|Credit card or pr...|
# |   mishandling of th...|Vehicle loan or l...|
# |   i have reached ou...|Credit reporting,...|
# |   i opened an accou...|Checking or savin...|
# |   to whom it may co...|Checking or savin...|
# |   my chase amazon c...|Credit card or pr...|
# |   i opened the savi...|Checking or savin...|
# |   a sofa love seat ...|Checking or savin...|
# |   my card went miss...|Checking or savin...|
# |   chase sent me an ...|Credit card or pr...|
# |   i made a purchase...|Checking or savin...|
# +-----------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Lemmatization, Stopwords, Pos Tagging, CountVectorizer.
# ---

# %%
from pyspark.ml import Pipeline, Transformer
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer
from pyspark.sql.functions import udf, col
from pyspark.sql.types import ArrayType, StringType
import sparknlp
from sparknlp.base import DocumentAssembler, Finisher
from sparknlp.annotator import Tokenizer as NLPTokenizer
from sparknlp.annotator import LemmatizerModel, PerceptronModel, StopWordsCleaner

# Iniciar sesión de Spark con Spark NLP
# spark = sparknlp.start()

# Document Assembler
document_assembler = DocumentAssembler() \
    .setInputCol("complaint_what_happened") \
    .setOutputCol("document")

# Tokenizer
tokenizer = NLPTokenizer() \
    .setInputCols(["document"]) \
    .setOutputCol("token")

# Stop Words Remover
stop_words_cleaner = StopWordsCleaner() \
    .setInputCols(["token"]) \
    .setOutputCol("cleanTokens") \
    .setCaseSensitive(False)

# POS Tagger
pos_tagger = PerceptronModel.pretrained("pos_anc") \
    .setInputCols(["document", "cleanTokens"]) \
    .setOutputCol("pos")

# Lemmatizer
lemmatizer = LemmatizerModel.pretrained("lemma_antbnc") \
    .setInputCols(["cleanTokens"]) \
    .setOutputCol("lemma")

# Finisher to extract results from annotations
finisher = Finisher() \
    .setInputCols(["lemma", "pos"]) \
    .setOutputCols(["finished_lemma", "finished_pos"]) \
    .setCleanAnnotations(False)

# Custom Transformer to remove pronouns and extract nouns
class NounExtractor(Transformer):
    def __init__(self, inputColPOS=None, inputColLemma=None, outputCol=None):
        super(NounExtractor, self).__init__()
        self.inputColPOS = inputColPOS
        self.inputColLemma = inputColLemma
        self.outputCol = outputCol

    def _transform(self, dataset):
        def extract_nouns(pos_tags, lemmas):
            noun_tags = ['NN', 'NNS', 'NNP', 'NNPS']
            return [lemma for pos, lemma in zip(pos_tags, lemmas) if pos in noun_tags]
        
        extract_nouns_udf = udf(extract_nouns, ArrayType(StringType()))
        return dataset.withColumn(self.outputCol, extract_nouns_udf(col(self.inputColPOS), col(self.inputColLemma)))

# Instantiate custom transformer
noun_extractor = NounExtractor(inputColPOS="finished_pos", inputColLemma="finished_lemma", outputCol="noun_tokens")

# Build the pipeline
pipeline = Pipeline(stages=[
    document_assembler,
    tokenizer,
    stop_words_cleaner,
    pos_tagger,
    lemmatizer,
    finisher,
    noun_extractor
])

# Fit and transform the data
pipeline_model = pipeline.fit(df_cleaned)
df_final = pipeline_model.transform(df_cleaned)
df_final.select("noun_tokens", "pos").show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# pos_anc download started this may take some time.
# Approximate size to download 3.9 MB
# [OK!]
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |noun_tokens                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |pos                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[morning, name, isand, appreciate, help, chase, bank, cardmember, service, chase, debt, verification, statement, bank, validate, debt, mail, month, debt, right, information, consumer, chase, accountthanks, advance, help]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |[{pos, 0, 3, JJ, {word -> good, sentence -> 0}, []}, {pos, 5, 11, NN, {word -> morning, sentence -> 0}, []}, {pos, 16, 19, NN, {word -> name, sentence -> 0}, []}, {pos, 21, 25, NN, {word -> isand, sentence -> 0}, []}, {pos, 29, 38, NN, {word -> appreciate, sentence -> 0}, []}, {pos, 56, 59, NN, {word -> help, sentence -> 0}, []}, {pos, 64, 66, VB, {word -> put, sentence -> 0}, []}, {pos, 70, 73, VB, {word -> stop, sentence -> 0}, []}, {pos, 78, 82, NN, {word -> chase, sentence -> 0}, []}, {pos, 84, 87, NN, {word -> bank, sentence -> 0}, []}, {pos, 89, 98, NN, {word -> cardmember, sentence -> 0}, []}, {pos, 100, 107, NNS, {word -> services, sentence -> 0}, []}, {pos, 116, 120, VBD, {word -> wrote, sentence -> 0}, []}, {pos, 125, 129, NN, {word -> chase, sentence -> 0}, []}, {pos, 131, 136, VBG, {word -> asking, sentence -> 0}, []}, {pos, 142, 145, NN, {word -> debt, sentence -> 0}, []}, {pos, 147, 158, NN, {word -> verification, sentence -> 0}, []}, {pos, 174, 177, VBD, {word -> sent, sentence -> 0}, []}, {pos, 184, 192, NN, {word -> statement, sentence -> 0}, []}, {pos, 207, 216, JJ, {word -> acceptable, sentence -> 0}, []}, {pos, 223, 228, VBG, {word -> asking, sentence -> 0}, []}, {pos, 234, 237, NN, {word -> bank, sentence -> 0}, []}, {pos, 242, 249, NN, {word -> validate, sentence -> 0}, []}, {pos, 255, 258, NN, {word -> debt, sentence -> 0}, []}, {pos, 260, 266, RB, {word -> instead, sentence -> 0}, []}, {pos, 275, 283, VBG, {word -> receiving, sentence -> 0}, []}, {pos, 285, 288, NN, {word -> mail, sentence -> 0}, []}, {pos, 290, 294, DT, {word -> every, sentence -> 0}, []}, {pos, 296, 300, NN, {word -> month, sentence -> 0}, []}, {pos, 312, 321, VBG, {word -> attempting, sentence -> 0}, []}, {pos, 326, 332, JJ, {word -> collect, sentence -> 0}, []}, {pos, 336, 339, NN, {word -> debt, sentence -> 0}, []}, {pos, 351, 355, NN, {word -> right, sentence -> 0}, []}, {pos, 360, 363, VB, {word -> know, sentence -> 0}, []}, {pos, 370, 380, NN, {word -> information, sentence -> 0}, []}, {pos, 387, 394, NN, {word -> consumer, sentence -> 0}, []}, {pos, 398, 402, NN, {word -> chase, sentence -> 0}, []}, {pos, 404, 416, NNS, {word -> accountthanks, sentence -> 0}, []}, {pos, 421, 427, NN, {word -> advance, sentence -> 0}, []}, {pos, 438, 441, NN, {word -> help, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                   ...
# |[mycard, agent, upgrade, anniversary, date, change, agent, information, order, upgrade, date, fromtowithout, consenthas, record, agent]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |[{pos, 2, 9, JJ, {word -> upgraded, sentence -> 0}, []}, {pos, 11, 16, NN, {word -> mycard, sentence -> 0}, []}, {pos, 30, 33, VBD, {word -> told, sentence -> 0}, []}, {pos, 42, 46, NN, {word -> agent, sentence -> 0}, []}, {pos, 60, 66, NN, {word -> upgrade, sentence -> 0}, []}, {pos, 71, 81, NN, {word -> anniversary, sentence -> 0}, []}, {pos, 83, 86, NN, {word -> date, sentence -> 0}, []}, {pos, 98, 103, NN, {word -> change, sentence -> 0}, []}, {pos, 108, 113, VBD, {word -> turned, sentence -> 0}, []}, {pos, 119, 123, NN, {word -> agent, sentence -> 0}, []}, {pos, 129, 134, VBG, {word -> giving, sentence -> 0}, []}, {pos, 143, 147, JJ, {word -> wrong, sentence -> 0}, []}, {pos, 149, 159, NN, {word -> information, sentence -> 0}, []}, {pos, 164, 168, NN, {word -> order, sentence -> 0}, []}, {pos, 173, 179, NN, {word -> upgrade, sentence -> 0}, []}, {pos, 185, 198, VBN, {word -> accountchanged, sentence -> 0}, []}, {pos, 203, 213, JJ, {word -> anniversary, sentence -> 0}, []}, {pos, 215, 218, NN, {word -> date, sentence -> 0}, []}, {pos, 220, 232, NN, {word -> fromtowithout, sentence -> 0}, []}, {pos, 237, 246, NN, {word -> consenthas, sentence -> 0}, []}, {pos, 252, 260, NN, {word -> recording, sentence -> 0}, []}, {pos, 269, 273, NN, {word -> agent, sentence -> 0}, []}, {pos, 283, 288, JJ, {word -> misled, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# |[chase, card, application, identity, consent, service, credit, identity, applicant]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |[{pos, 0, 4, NN, {word -> chase, sentence -> 0}, []}, {pos, 6, 9, NN, {word -> card, sentence -> 0}, []}, {pos, 15, 22, VBD, {word -> reported, sentence -> 0}, []}, {pos, 28, 34, RB, {word -> however, sentence -> 0}, []}, {pos, 36, 45, JJ, {word -> fraudulent, sentence -> 0}, []}, {pos, 47, 57, NN, {word -> application, sentence -> 0}, []}, {pos, 69, 77, JJ, {word -> submitted, sentence -> 0}, []}, {pos, 82, 89, NN, {word -> identity, sentence -> 0}, []}, {pos, 91, 97, IN, {word -> without, sentence -> 0}, []}, {pos, 102, 108, NN, {word -> consent, sentence -> 0}, []}, {pos, 113, 124, RB, {word -> fraudulently, sentence -> 0}, []}, {pos, 126, 131, VB, {word -> obtain, sentence -> 0}, []}, {pos, 133, 140, NNS, {word -> services, sentence -> 0}, []}, {pos, 149, 154, VB, {word -> extend, sentence -> 0}, []}, {pos, 156, 161, NN, {word -> credit, sentence -> 0}, []}, {pos, 163, 169, IN, {word -> without, sentence -> 0}, []}, {pos, 171, 179, VBG, {word -> verifying, sentence -> 0}, []}, {pos, 185, 192, NN, {word -> identity, sentence -> 0}, []}, {pos, 201, 209, NN, {word -> applicant, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# |[book, aticket, offer, ticket, reward, card, information, offer, minute, screen, decision, contactedand, bank, chase, bank, notification, screen, chase, representative, application, state, information, theoffer, credit, offer, account, statement, purchase, ticket, account, application, withdraw, representative, application, request, proceed, application, chase, representative, chase, fact, go, credit, account, name, credit, report, chase, information, credit, report, process, application, consent, error]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |[{pos, 10, 15, VBG, {word -> trying, sentence -> 0}, []}, {pos, 20, 23, NN, {word -> book, sentence -> 0}, []}, {pos, 25, 31, NN, {word -> aticket, sentence -> 0}, []}, {pos, 35, 38, VBD, {word -> came, sentence -> 0}, []}, {pos, 40, 45, IN, {word -> across, sentence -> 0}, []}, {pos, 50, 54, NN, {word -> offer, sentence -> 0}, []}, {pos, 67, 73, VBD, {word -> applied, sentence -> 0}, []}, {pos, 75, 81, IN, {word -> towards, sentence -> 0}, []}, {pos, 87, 92, NN, {word -> ticket, sentence -> 0}, []}, {pos, 99, 105, VBN, {word -> applied, sentence -> 0}, []}, {pos, 113, 119, NNS, {word -> rewards, sentence -> 0}, []}, {pos, 121, 124, NN, {word -> card, sentence -> 0}, []}, {pos, 128, 130, VBD, {word -> put, sentence -> 0}, []}, {pos, 138, 148, NN, {word -> information, sentence -> 0}, []}, {pos, 158, 162, NN, {word -> offer, sentence -> 0}, []}, {pos, 168, 173, IN, {word -> within, sentence -> 0}, []}, {pos, 175, 178, JJR, {word -> less, sentence -> 0}, []}, {pos, 187, 192, NN, {word -> minute, sentence -> 0}, []}, {pos, 198, 205, JJ, {word -> notified, sentence -> 0}, []}, {pos, 207, 209, IN, {word -> via, sentence -> 0}, []}, {pos, 215, 220, NN, {word -> screen, sentence -> 0}, []}, {pos, 229, 236, NN, {word -> decision, sentence -> 0}, []}, {pos, 251, 254, VBD, {word -> made, sentence -> 0}, []}, {pos, 258, 268, RB, {word -> immediately, sentence -> 0}, []}, {pos, 270, 281, NN, {word -> contactedand, sentence -> 0}, []}, {pos, 287, 294, VBD, {word -> referred, sentence -> 0}, []}, {pos, 299, 303, VB, {word -> chase, sentence -> 0}, []}, {pos, 305, 308, NN, {word -> bank, sentence -> 0}, []}, {pos, 317, 327, RB, {word -> immediately, sentence -> 0}, []}, {pos, 329, 337, VBD, {word -> contacted, sentence -> 0}, []}, {pos, 339, 343, NN, {word -> chase, sentence -> 0}, []}, {pos, 345, 348, NN, {word -> bank, sentence -> 0}, []}, {pos, 350, 355, IN, {word -> within, sentence -> 0}, []}, {pos, 374, 380, VBG, {word -> getting, sentence -> 0}, []}, {pos, 386, 397, NN, {word -> notification, sentence -> 0}, []}, {pos, 406, 411, NN, {word -> screen, sentence -> 0}, []}, {pos, 423, 426, VBD, {word -> told, sentence -> 0}, []}, {pos, 435, 439, NN, {word -> chase, sentence -> 0}, []}, {pos, 441, 454, NN, {word -> representative, sentence -> 0}, []}, {pos, 458, 462, VBD, {word -> spoke, sentence -> 0}, []}, {pos, 477, 487, NN, {word -> application, sentence -> 0}, []}, {pos, 493, 498, VBD, {word -> denied, sentence -> 0}, []}, {pos, 518, 522, NN, {word -> state, sentence -> 0}, []}, {pos, 530, 534, VBD, {word -> asked, sentence -> 0}, []}, {pos, 545, 555, NN, {word -> information, sentence -> 0}, []}, { ...
# |[son, check, deposit, chase, account, fund, chase, bank, account, money, son, check, money, chase, bank, refuse, pay, money, grand, son, chase, time, call, verify, check, owner, country, time, date, check, numberclaim, number, iswith, chase]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |[{pos, 3, 7, JJ, {word -> grand, sentence -> 0}, []}, {pos, 9, 11, NN, {word -> son, sentence -> 0}, []}, {pos, 13, 16, VBP, {word -> give, sentence -> 0}, []}, {pos, 21, 25, NN, {word -> check, sentence -> 0}, []}, {pos, 34, 40, NN, {word -> deposit, sentence -> 0}, []}, {pos, 53, 57, NN, {word -> chase, sentence -> 0}, []}, {pos, 59, 65, NN, {word -> account, sentence -> 0}, []}, {pos, 73, 76, NN, {word -> fund, sentence -> 0}, []}, {pos, 78, 82, JJ, {word -> clear, sentence -> 0}, []}, {pos, 87, 91, NN, {word -> chase, sentence -> 0}, []}, {pos, 93, 96, NN, {word -> bank, sentence -> 0}, []}, {pos, 98, 103, VBD, {word -> closed, sentence -> 0}, []}, {pos, 108, 114, NN, {word -> account, sentence -> 0}, []}, {pos, 116, 120, RB, {word -> never, sentence -> 0}, []}, {pos, 122, 125, VBD, {word -> paid, sentence -> 0}, []}, {pos, 133, 137, NN, {word -> money, sentence -> 0}, []}, {pos, 144, 147, VBD, {word -> said, sentence -> 0}, []}, {pos, 154, 157, VBP, {word -> need, sentence -> 0}, []}, {pos, 162, 166, JJ, {word -> speek, sentence -> 0}, []}, {pos, 176, 180, JJ, {word -> grand, sentence -> 0}, []}, {pos, 182, 184, NN, {word -> son, sentence -> 0}, []}, {pos, 186, 190, NN, {word -> check, sentence -> 0}, []}, {pos, 196, 200, JJ, {word -> clear, sentence -> 0}, []}, {pos, 202, 206, NN, {word -> money, sentence -> 0}, []}, {pos, 212, 217, VBG, {word -> taking, sentence -> 0}, []}, {pos, 225, 229, NN, {word -> chase, sentence -> 0}, []}, {pos, 231, 234, NN, {word -> bank, sentence -> 0}, []}, {pos, 236, 241, NN, {word -> refuse, sentence -> 0}, []}, {pos, 246, 248, NN, {word -> pay, sentence -> 0}, []}, {pos, 256, 260, NN, {word -> money, sentence -> 0}, []}, {pos, 265, 269, NN, {word -> grand, sentence -> 0}, []}, {pos, 271, 273, NN, {word -> son, sentence -> 0}, []}, {pos, 275, 280, VBD, {word -> called, sentence -> 0}, []}, {pos, 282, 286, NN, {word -> chase, sentence -> 0}, []}, {pos, 289, 293, NNS, {word -> times, sentence -> 0}, []}, {pos, 300, 303, VBD, {word -> told, sentence -> 0}, []}, {pos, 318, 321, NN, {word -> call, sentence -> 0}, []}, {pos, 334, 339, NN, {word -> verify, sentence -> 0}, []}, {pos, 345, 349, NN, {word -> check, sentence -> 0}, []}, {pos, 351, 355, NN, {word -> owner, sentence -> 0}, []}, {pos, 371, 377, NN, {word -> country, sentence -> 0}, []}, {pos, 388, 391, NN, {word -> time, sentence -> 0}, []}, {pos, 394, 397, NN, {word -> date, sentence -> 0}, []}, {pos, 399, 404, VB, {word -> happen, sentence -> 0}, []}, {pos, 407, 411, NN, {word -> check, sentence -> 0}, []}, {pos, 413, 423, NN, {word -> numberclaim, sentence -> 0}, []}, {pos, 425, 430, NN, {word -> nu ...
# |[inquiry]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |[{pos, 8, 13, VB, {word -> please, sentence -> 0}, []}, {pos, 15, 20, VB, {word -> remove, sentence -> 0}, []}, {pos, 22, 28, NN, {word -> inquiry, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |[notice, jp, morgan, chase, account, debit, card, tuesday, thursday, branch, customer, service, representative, account, branch, fund, deposit, place, employment, bank, customer, service, representative, fund, business, day, saturday, branch, fund, friday, account, fund, statement, business, day, tuesdaywould, date, fund, bank, teller, chase, check, business, day, fund, account, bind, fee, rent, car, payment, notice, thing, peace, mind, fact, chase, situation, bank, teller, inform, account, look, reserve, right, close, account, time, protocol, notice, form, document, notice, thing, peace, mind, fact, chase, situation, bank, teller, inform, account, look, reserve, right, close, account, time, protocol, notice, form, document, situation, livelihood, dont, deal]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |[{pos, 9, 14, NN, {word -> notice, sentence -> 0}, []}, {pos, 16, 17, NN, {word -> jp, sentence -> 0}, []}, {pos, 19, 24, NN, {word -> morgan, sentence -> 0}, []}, {pos, 26, 30, NN, {word -> chase, sentence -> 0}, []}, {pos, 32, 41, VBD, {word -> restricted, sentence -> 0}, []}, {pos, 46, 52, NN, {word -> account, sentence -> 0}, []}, {pos, 60, 64, NN, {word -> debit, sentence -> 0}, []}, {pos, 66, 69, NN, {word -> card, sentence -> 0}, []}, {pos, 71, 77, NNP, {word -> tuesday, sentence -> 0}, []}, {pos, 83, 90, NNP, {word -> thursday, sentence -> 0}, []}, {pos, 95, 98, VBD, {word -> went, sentence -> 0}, []}, {pos, 107, 112, NN, {word -> branch, sentence -> 0}, []}, {pos, 126, 132, VBN, {word -> advised, sentence -> 0}, []}, {pos, 139, 146, NN, {word -> customer, sentence -> 0}, []}, {pos, 148, 154, NN, {word -> service, sentence -> 0}, []}, {pos, 156, 169, NN, {word -> representative, sentence -> 0}, []}, {pos, 179, 185, NN, {word -> account, sentence -> 0}, []}, {pos, 193, 200, RB, {word -> actually, sentence -> 0}, []}, {pos, 205, 210, VBD, {word -> closed, sentence -> 0}, []}, {pos, 214, 217, VBD, {word -> went, sentence -> 0}, []}, {pos, 228, 233, NN, {word -> branch, sentence -> 0}, []}, {pos, 238, 240, VB, {word -> see, sentence -> 0}, []}, {pos, 252, 257, VB, {word -> remove, sentence -> 0}, []}, {pos, 263, 267, NNS, {word -> funds, sentence -> 0}, []}, {pos, 287, 295, RB, {word -> currently, sentence -> 0}, []}, {pos, 303, 306, RB, {word -> well, sentence -> 0}, []}, {pos, 317, 322, JJ, {word -> direct, sentence -> 0}, []}, {pos, 324, 330, NN, {word -> deposit, sentence -> 0}, []}, {pos, 340, 344, NN, {word -> place, sentence -> 0}, []}, {pos, 349, 358, NN, {word -> employment, sentence -> 0}, []}, {pos, 369, 376, VBD, {word -> returned, sentence -> 0}, []}, {pos, 382, 385, NN, {word -> bank, sentence -> 0}, []}, {pos, 387, 395, JJ, {word -> associate, sentence -> 0}, []}, {pos, 405, 412, NN, {word -> customer, sentence -> 0}, []}, {pos, 414, 420, NN, {word -> service, sentence -> 0}, []}, {pos, 422, 435, NN, {word -> representative, sentence -> 0}, []}, {pos, 437, 443, VBD, {word -> assured, sentence -> 0}, []}, {pos, 457, 461, NNS, {word -> funds, sentence -> 0}, []}, {pos, 469, 472, VBP, {word -> post, sentence -> 0}, []}, {pos, 483, 485, MD, {word -> may, sentence -> 0}, []}, {pos, 487, 490, VB, {word -> take, sentence -> 0}, []}, {pos, 495, 504, JJ, {word -> additional, sentence -> 0}, []}, {pos, 506, 513, NN, {word -> business, sentence -> 0}, []}, {pos, 515, 517, NN, {word -> day, sentence -> 0}, []}, {pos, 524, 531, NNP, {word -> saturday, sentence -> 0}, []}, {pos, 535, 54 ...
# |[summer, month, experience, decline, income, employment, request, month, payment, extension, auto, loan, company, chase, fours, year, payment, extension, auto, loan, payment, request, month, payment, extension, year, situation, supervisor, avail, discussion, reason, decline, reason, denial, office, director, communication, jpmorgan, chase, co, representative, chase, followup, week, ofoffice, representative, role, help, matter, representative, conference, call, department, request, information, request, policy, change, explanation, representative, letter, explanation, receivedletters, reason, policy, change, cfpb, help, payment, extension, request, reason, denial]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |[{pos, 11, 16, NN, {word -> summer, sentence -> 0}, []}, {pos, 18, 23, NNS, {word -> months, sentence -> 0}, []}, {pos, 27, 36, NN, {word -> experience, sentence -> 0}, []}, {pos, 40, 46, NN, {word -> decline, sentence -> 0}, []}, {pos, 48, 53, NN, {word -> income, sentence -> 0}, []}, {pos, 55, 57, JJ, {word -> due, sentence -> 0}, []}, {pos, 65, 74, NN, {word -> employment, sentence -> 0}, []}, {pos, 76, 84, RB, {word -> therefore, sentence -> 0}, []}, {pos, 88, 94, NN, {word -> request, sentence -> 0}, []}, {pos, 98, 100, CD, {word -> one, sentence -> 0}, []}, {pos, 102, 106, NN, {word -> month, sentence -> 0}, []}, {pos, 108, 114, NN, {word -> payment, sentence -> 0}, []}, {pos, 116, 124, NN, {word -> extension, sentence -> 0}, []}, {pos, 134, 137, NN, {word -> auto, sentence -> 0}, []}, {pos, 139, 142, NN, {word -> loan, sentence -> 0}, []}, {pos, 144, 150, NN, {word -> company, sentence -> 0}, []}, {pos, 152, 156, NN, {word -> chase, sentence -> 0}, []}, {pos, 166, 169, JJ, {word -> past, sentence -> 0}, []}, {pos, 171, 176, RB, {word -> almost, sentence -> 0}, []}, {pos, 178, 182, NNS, {word -> fours, sentence -> 0}, []}, {pos, 184, 188, NNS, {word -> years, sentence -> 0}, []}, {pos, 193, 199, VBP, {word -> request, sentence -> 0}, []}, {pos, 205, 211, NN, {word -> payment, sentence -> 0}, []}, {pos, 213, 221, NN, {word -> extension, sentence -> 0}, []}, {pos, 226, 232, VBN, {word -> granted, sentence -> 0}, []}, {pos, 241, 245, RB, {word -> never, sentence -> 0}, []}, {pos, 252, 261, JJ, {word -> delinquent, sentence -> 0}, []}, {pos, 271, 274, NN, {word -> auto, sentence -> 0}, []}, {pos, 276, 279, NN, {word -> loan, sentence -> 0}, []}, {pos, 281, 287, NN, {word -> payment, sentence -> 0}, []}, {pos, 289, 295, RB, {word -> however, sentence -> 0}, []}, {pos, 304, 310, NN, {word -> request, sentence -> 0}, []}, {pos, 318, 320, CD, {word -> one, sentence -> 0}, []}, {pos, 322, 326, NN, {word -> month, sentence -> 0}, []}, {pos, 328, 334, NN, {word -> payment, sentence -> 0}, []}, {pos, 336, 344, NN, {word -> extension, sentence -> 0}, []}, {pos, 350, 355, VBN, {word -> denied, sentence -> 0}, []}, {pos, 362, 365, NN, {word -> year, sentence -> 0}, []}, {pos, 369, 377, VBD, {word -> explained, sentence -> 0}, []}, {pos, 382, 390, NN, {word -> situation, sentence -> 0}, []}, {pos, 395, 408, JJ, {word -> representative, sentence -> 0}, []}, {pos, 418, 427, NN, {word -> supervisor, sentence -> 0}, []}, {pos, 437, 441, NN, {word -> avail, sentence -> 0}, []}, {pos, 451, 457, JJ, {word -> lengthy, sentence -> 0}, []}, {pos, 459, 468, NN, {word -> discussion, sentence -> 0}, []}, {pos, 474 ...
# ...
# |[chase, email, today, title, information, change, chase, account, use, title, ad, communication, force, arbitration, something, part, contract, method, opt, information, people, problem, chase, close, account, opt, chase, email, require, mail, letter, information, order, loss, time, money, people, malpractice, chase]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |[{pos, 0, 4, NN, {word -> chase, sentence -> 0}, []}, {pos, 6, 9, VBD, {word -> sent, sentence -> 0}, []}, {pos, 17, 21, NN, {word -> email, sentence -> 0}, []}, {pos, 23, 27, NN, {word -> today, sentence -> 0}, []}, {pos, 38, 46, JJ, {word -> innocuous, sentence -> 0}, []}, {pos, 48, 52, NN, {word -> title, sentence -> 0}, []}, {pos, 55, 63, JJ, {word -> important, sentence -> 0}, []}, {pos, 65, 75, NN, {word -> information, sentence -> 0}, []}, {pos, 77, 85, VBG, {word -> regarding, sentence -> 0}, []}, {pos, 87, 93, NNS, {word -> changes, sentence -> 0}, []}, {pos, 103, 107, NN, {word -> chase, sentence -> 0}, []}, {pos, 109, 115, NN, {word -> account, sentence -> 0}, []}, {pos, 124, 128, RB, {word -> often, sentence -> 0}, []}, {pos, 130, 132, NN, {word -> use, sentence -> 0}, []}, {pos, 134, 140, JJ, {word -> similar, sentence -> 0}, []}, {pos, 142, 147, NNS, {word -> titles, sentence -> 0}, []}, {pos, 153, 155, NNS, {word -> ads, sentence -> 0}, []}, {pos, 167, 180, NNS, {word -> communications, sentence -> 0}, []}, {pos, 196, 200, NN, {word -> force, sentence -> 0}, []}, {pos, 210, 216, JJ, {word -> binding, sentence -> 0}, []}, {pos, 218, 228, NN, {word -> arbitration, sentence -> 0}, []}, {pos, 231, 237, IN, {word -> despite, sentence -> 0}, []}, {pos, 244, 248, RB, {word -> never, sentence -> 0}, []}, {pos, 256, 264, NN, {word -> something, sentence -> 0}, []}, {pos, 272, 277, VBD, {word -> agreed, sentence -> 0}, []}, {pos, 286, 290, RB, {word -> never, sentence -> 0}, []}, {pos, 300, 303, NN, {word -> part, sentence -> 0}, []}, {pos, 312, 319, NN, {word -> contract, sentence -> 0}, []}, {pos, 352, 358, VBP, {word -> include, sentence -> 0}, []}, {pos, 362, 367, NN, {word -> method, sentence -> 0}, []}, {pos, 372, 374, NN, {word -> opt, sentence -> 0}, []}, {pos, 392, 401, JJ, {word -> additional, sentence -> 0}, []}, {pos, 403, 413, NN, {word -> information, sentence -> 0}, []}, {pos, 425, 436, VBZ, {word -> consequences, sentence -> 0}, []}, {pos, 439, 442, JJ, {word -> many, sentence -> 0}, []}, {pos, 450, 455, NNS, {word -> people, sentence -> 0}, []}, {pos, 457, 459, VBP, {word -> ive, sentence -> 0}, []}, {pos, 461, 464, VBN, {word -> seen, sentence -> 0}, []}, {pos, 481, 487, JJ, {word -> similar, sentence -> 0}, []}, {pos, 489, 495, NN, {word -> problem, sentence -> 0}, []}, {pos, 501, 506, JJ, {word -> afraid, sentence -> 0}, []}, {pos, 513, 517, NN, {word -> chase, sentence -> 0}, []}, {pos, 524, 528, NN, {word -> close, sentence -> 0}, []}, {pos, 536, 542, NN, {word -> account, sentence -> 0}, []}, {pos, 552, 554, NN, {word -> opt, sentence -> 0}, []}, {pos, 565, 568, R ...
# |[purchase, withon, amount, transaction, dispute, case, chase, bank, charge, account, sunday, credit, charge, monday, charge, post, credit, debt, card, monday, use, work, chase, bank, oninnevada, account, fraudulent, activity, fraud, account, dispute, department, dispute, case, duplicate, charge, fromi, duplicate, charge, credit, account, day, chase, dispute, department, mondayand, thawould, credit, account, dispute, escalation, manager, care, chase, decision, close, account, customer, chase, foryears, character, dispute, agent, character, slander, account, chase, chase, check, account, chase, check, account, record, closure, chase, nothing, file, dispute, charge, dispute, case]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |[{pos, 2, 5, VBN, {word -> made, sentence -> 0}, []}, {pos, 9, 16, NN, {word -> purchase, sentence -> 0}, []}, {pos, 18, 23, NN, {word -> withon, sentence -> 0}, []}, {pos, 33, 38, NN, {word -> amount, sentence -> 0}, []}, {pos, 50, 56, VBN, {word -> charged, sentence -> 0}, []}, {pos, 58, 62, RB, {word -> twice, sentence -> 0}, []}, {pos, 73, 83, NN, {word -> transaction, sentence -> 0}, []}, {pos, 87, 92, VBN, {word -> placed, sentence -> 0}, []}, {pos, 96, 103, NNS, {word -> disputes, sentence -> 0}, []}, {pos, 105, 108, NN, {word -> case, sentence -> 0}, []}, {pos, 115, 119, NN, {word -> chase, sentence -> 0}, []}, {pos, 121, 124, NN, {word -> bank, sentence -> 0}, []}, {pos, 137, 143, VBD, {word -> noticed, sentence -> 0}, []}, {pos, 149, 154, NN, {word -> charge, sentence -> 0}, []}, {pos, 162, 168, NN, {word -> account, sentence -> 0}, []}, {pos, 172, 177, VBD, {word -> called, sentence -> 0}, []}, {pos, 179, 182, RB, {word -> back, sentence -> 0}, []}, {pos, 187, 192, NNP, {word -> sunday, sentence -> 0}, []}, {pos, 205, 215, JJ, {word -> provisional, sentence -> 0}, []}, {pos, 217, 222, NN, {word -> credit, sentence -> 0}, []}, {pos, 232, 237, NN, {word -> charge, sentence -> 0}, []}, {pos, 252, 257, NNP, {word -> monday, sentence -> 0}, []}, {pos, 266, 269, VBD, {word -> told, sentence -> 0}, []}, {pos, 275, 280, NN, {word -> charge, sentence -> 0}, []}, {pos, 289, 292, NN, {word -> post, sentence -> 0}, []}, {pos, 303, 313, JJ, {word -> provisional, sentence -> 0}, []}, {pos, 315, 320, NN, {word -> credit, sentence -> 0}, []}, {pos, 331, 338, VBN, {word -> provided, sentence -> 0}, []}, {pos, 342, 345, VBN, {word -> used, sentence -> 0}, []}, {pos, 350, 353, NN, {word -> debt, sentence -> 0}, []}, {pos, 355, 358, NN, {word -> card, sentence -> 0}, []}, {pos, 363, 368, NNP, {word -> monday, sentence -> 0}, []}, {pos, 376, 380, VBD, {word -> tried, sentence -> 0}, []}, {pos, 385, 387, NN, {word -> use, sentence -> 0}, []}, {pos, 415, 418, NN, {word -> work, sentence -> 0}, []}, {pos, 422, 425, VBD, {word -> went, sentence -> 0}, []}, {pos, 430, 434, NN, {word -> chase, sentence -> 0}, []}, {pos, 436, 439, NN, {word -> bank, sentence -> 0}, []}, {pos, 441, 450, NN, {word -> oninnevada, sentence -> 0}, []}, {pos, 460, 463, VBD, {word -> told, sentence -> 0}, []}, {pos, 473, 479, NN, {word -> account, sentence -> 0}, []}, {pos, 485, 490, VBD, {word -> closed, sentence -> 0}, []}, {pos, 492, 494, JJ, {word -> due, sentence -> 0}, []}, {pos, 499, 508, NN, {word -> fraudulent, sentence -> 0}, []}, {pos, 510, 517, NN, {word -> activity, sentence -> 0}, []}, {pos, 525, 531, VBD, {word -> sh ...
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
from pyspark.sql.functions import udf, col
from pyspark.sql.types import ArrayType, StringType

# 1. Vectorización: Aplicar CountVectorizer
count_vectorizer = CountVectorizer(inputCol="noun_tokens", outputCol="features")
cv_model = count_vectorizer.fit(df_final)  # Ajuste del modelo de vectorización
df_cv = cv_model.transform(df_final)  # Transformación de los datos para obtener la columna "features"

# 2. Entrenamiento del modelo LDA
lda = LDA(k=5, maxIter=10, featuresCol="features")
lda_model = lda.fit(df_cv)

# 3. Obtener los temas
topics = lda_model.describeTopics()

# 4. Mapear índices a palabras
# Extraer vocabulario de CountVectorizer
vocab = cv_model.vocabulary

# Definir función para mapear índices a palabras
def indices_to_words(indices):
    return [vocab[idx] for idx in indices]

# Crear UDF para aplicar la función
indices_to_words_udf = udf(indices_to_words, ArrayType(StringType()))

# Añadir columna con palabras correspondientes a los índices
topics_with_words = topics.withColumn("terms", indices_to_words_udf(col("termIndices")))

# Mostrar temas con palabras en lugar de índices
topics_with_words.show()

# %%
topics_with_words.select("topic", "terms", "termWeights").show(truncate=False)

# %% [markdown]
# ## (alternativa) Embeddings

# %%
# Importar las librerías necesarias
from pyspark.ml import Pipeline
from pyspark.ml.clustering import KMeans
from sparknlp.base import DocumentAssembler, EmbeddingsFinisher
from sparknlp.annotator import Tokenizer, WordEmbeddingsModel, SentenceEmbeddings
from pyspark.ml.feature import StringIndexer, StopWordsRemover
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql.functions import col

# Definir las etapas del pipeline
document_assembler = DocumentAssembler() \
    .setInputCol("complaint_what_happened") \
    .setOutputCol("document")

tokenizer = Tokenizer() \
    .setInputCols(["document"]) \
    .setOutputCol("token")

stop_words_cleaner = StopWordsCleaner() \
    .setInputCols(["token"]) \
    .setOutputCol("cleanTokens")

# Usar embeddings ligeros
embeddings = WordEmbeddingsModel.pretrained("glove_100d") \
    .setInputCols(["document", "cleanTokens"]) \
    .setOutputCol("embeddings")

sentence_embeddings = SentenceEmbeddings() \
    .setInputCols(["document", "embeddings"]) \
    .setOutputCol("sentence_embeddings") \
    .setPoolingStrategy("AVERAGE")

# Usar EmbeddingsFinisher para extraer los embeddings
embeddings_finisher = EmbeddingsFinisher() \
    .setInputCols(["sentence_embeddings"]) \
    .setOutputCols(["finished_embeddings"]) \
    .setOutputAsVector(True) \
    .setCleanAnnotations(False)

# Construir el pipeline
pipeline = Pipeline(stages=[
    document_assembler,
    tokenizer,
    stop_words_cleaner,
    embeddings,
    sentence_embeddings,
    embeddings_finisher
])

# Ajustar el pipeline y transformar los datos
pipeline_model = pipeline.fit(df_cleaned)
df_embeddings = pipeline_model.transform(df_cleaned)
df_embeddings.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# +-----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |complaint_what_happened|            category|            document|               token|         cleanTokens|          embeddings| sentence_embeddings| finished_embeddings|
# +-----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |   good morning my n...|Debt collection+C...|[{document, 0, 44...|[{token, 0, 3, go...|[{token, 0, 3, go...|[{word_embeddings...|[{sentence_embedd...|[[0.0094272485002...|
# |   i upgraded mycard...|Credit card or pr...|[{document, 0, 29...|[{token, 0, 0, i,...|[{token, 2, 9, up...|[{word_embeddings...|[{sentence_embedd...|[[0.0441840477287...|
# |   chase card was re...|Credit reporting,...|[{document, 0, 20...|[{token, 0, 4, ch...|[{token, 0, 4, ch...|[{word_embeddings...|[{sentence_embedd...|[[0.2390943616628...|
# |   on  while trying ...|Credit reporting,...|[{document, 0, 14...|[{token, 0, 1, on...|[{token, 10, 15, ...|[{word_embeddings...|[{sentence_embedd...|[[0.0198674425482...|
# |   my grand son give...|Checking or savin...|[{document, 0, 44...|[{token, 0, 1, my...|[{token, 3, 7, gr...|[{word_embeddings...|[{sentence_embedd...|[[0.1229684203863...|
# |   can you please re...|Credit reporting,...|[{document, 0, 28...|[{token, 0, 2, ca...|[{token, 8, 13, p...|[{word_embeddings...|[{sentence_embedd...|[[-0.615233004093...|
# |   with out notice j...|Checking or savin...|[{document, 0, 22...|[{token, 0, 3, wi...|[{token, 9, 14, n...|[{word_embeddings...|[{sentence_embedd...|[[-0.020497435703...|
# |   during the summer...|Vehicle loan or l...|[{document, 0, 13...|[{token, 0, 5, du...|[{token, 11, 16, ...|[{word_embeddings...|[{sentence_embedd...|[[0.0993173122406...|
# |   oni made a  payme...|Money transfer, v...|[{document, 0, 33...|[{token, 0, 2, on...|[{token, 0, 2, on...|[{word_embeddings...|[{sentence_embedd...|[[-0.007192286197...|
# |   i have a chase cr...|Credit card or pr...|[{document, 0, 12...|[{token, 0, 0, i,...|[{token, 9, 13, c...|[{word_embeddings...|[{sentence_embedd...|[[-0.042179744690...|
# |   mishandling of th...|Vehicle loan or l...|[{document, 0, 44...|[{token, 0, 10, m...|[{token, 0, 10, m...|[{word_embeddings...|[{sentence_embedd...|[[0.1074732467532...|
# |   i have reached ou...|Credit reporting,...|[{document, 0, 72...|[{token, 0, 0, i,...|[{token, 7, 13, r...|[{word_embeddings...|[{sentence_embedd...|[[-0.005070750601...|
# |   i opened an accou...|Checking or savin...|[{document, 0, 36...|[{token, 0, 0, i,...|[{token, 2, 7, op...|[{word_embeddings...|[{sentence_embedd...|[[-0.002020800719...|
# |   to whom it may co...|Checking or savin...|[{document, 0, 54...|[{token, 0, 1, to...|[{token, 11, 13, ...|[{word_embeddings...|[{sentence_embedd...|[[-0.010806971229...|
# |   my chase amazon c...|Credit card or pr...|[{document, 0, 18...|[{token, 0, 1, my...|[{token, 3, 7, ch...|[{word_embeddings...|[{sentence_embedd...|[[0.0378467142581...|
# |   i opened the savi...|Checking or savin...|[{document, 0, 46...|[{token, 0, 0, i,...|[{token, 2, 7, op...|[{word_embeddings...|[{sentence_embedd...|[[0.0806116089224...|
# |   a sofa love seat ...|Checking or savin...|[{document, 0, 13...|[{token, 0, 0, a,...|[{token, 2, 5, so...|[{word_embeddings...|[{sentence_embedd...|[[0.1000872254371...|
# |   my card went miss...|Checking or savin...|[{document, 0, 17...|[{token, 0, 1, my...|[{token, 3, 6, ca...|[{word_embeddings...|[{sentence_embedd...|[[0.1008810028433...|
# |   chase sent me an ...|Credit card or pr...|[{document, 0, 91...|[{token, 0, 4, ch...|[{token, 0, 4, ch...|[{word_embeddings...|[{sentence_embedd...|[[-0.061259735375...|
# |   i made a purchase...|Checking or savin...|[{document, 0, 17...|[{token, 0, 0, i,...|[{token, 2, 5, ma...|[{word_embeddings...|[{sentence_embedd...|[[0.0778432786464...|
# +-----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df_embeddings.select("sentence_embeddings", "finished_embeddings").show(5, truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |sentence_embeddings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[{sentence_embeddings, 0, 441, good morning my name isand i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase accountthanks in advance for your help, {sentence -> 0, token -> good morning my name isand i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase accountthanks in advance for your help, pieceId -> -1, isWordStart -> true}, [0.0094272485, 0.01952864, 0.16779433, -0.09372918, -0.033593517, 0.053073496, -0.28913328, 0.028229456, 0.024333278, -0.08044485, 0.19223687, 0.17729707, -0.057825815, 0.0029570498, 0.00866171, -0.18238783, 0.1546252, 0.011292482, -0.27483648, 0.18970779, 0.021204215, -0.041096013, -0.025709653, 0.027833495, -0.12580714, -0.08809138, -0.23374729, -0.25480324, 0.07830247, -0.0260297, 0.10056081, 0.3252041, -0.13843302, 0.05287251, 0.022089817, 0.06982393, -0.0126829045, 0.0027987536, 0.03201678, -0.13236861, -0.1721239, -0.15356591, -0.04047898, -0.20693572, -0.20701842, 0.02980712, -0.06502811, -0.277541, -0.14460905, -0.7104145, 0.19454207, 0.09497281, 0.18850218, 0.6791037, -0.070211805, -1.6970276, -0.076072425, -0.2873717, 1.426943, 0.30658644, -0.02277567, 0.22841167, -0.20706753, -0.040689033, 0.42185044, -0.016345493, 0.15776661, 0.46413174, 0.2883012, -0.16276188, -0.1039391, -0.21219686, -0.22227116, -0.46871153, 0.19966516, 0.2738503, -0.16687953, 0.027796615, -0.83454925, -0.16036543, 0.5913062, 0.058098353, -0.32966882, -0.15192959, -0.95951355, -0.18983275, 0.06156265, -0.034607083, -0.10614703, -0.17632203, -0.09468867, 0.015645627, 0.05390038, -0.24185753, -0.3335685, 0.12450726, 0.13597581, -0.012314148, 0.31467506, 0.2040679]}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |[{sentence_embeddings, 0, 291, i upgraded mycard in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the accountchanged my anniversary date fromtowithout my consenthas the recording of the agent who was misled me, {sentence -> 0, token -> i upgraded mycard in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the accountchanged my anniversary date fromtowithout my consenthas the recording of the agent who was misled me, pieceId -> -1, isWordStart -> true}, [0.044184048, -0.23066342, 0.2910797, -0.016270306, -0.009582354, -0.18493633, 0.009688736, 0.017471565, 0.06093813, 0.21593995, 0.12728213, -0.08272118, 0.18857192, -0.063930914, 0.091811076, -0.07753362, 0.4003904, -0.029179739, -0.23712964, 0.12694857, -0.14225174, -0.2483156, 0.0065432163, -0.024021303, 0.012849911, -0.0812587, 0.009499889, -0.07964632, 0.10372599, 0.12838851, 0.012660612, 0.44726887, -0.04686568, 0.07529914, -0.045154568, 0.034071222, -0.0880007, -0.052639257, -0.04963682, -0.2013057, -0.049699556, -0.06919005, 0.26139256, -0.06242087, 0.015502949, -0.14088155, -0.063517705, -0.34541473, 0.05808514, -0.56439686, 0.35994372, -0.008536086, 0.10918948, 0.57079077, -0.15858305, -1.4392418, -0.15340763, -0.037934862, 1.154742, 0.32105923, -0.24495177, 0.537263, -0.15222998, -0.0964294, 0.37251994, -0.20481741, 0.06696523, 0.16595964, 0.07954399, 0.0018703374, 0.0076189125, -0.12070711, -0.23108815, -0.3065992, 0.115541264, 0.07513966, 0.018482042, -0.0022684361, -0.6401191, -0.13263331, 0.38869414, -0.097771645, -0.14788128, -0.051690873, -0.8737404, 0.012598545, 0.20581096, -0.123105876, -0.12151562, -0.13940653, -0.12494869, -0.078108, -0.02605991, -0.16333325, -0.17998119, -0.062139813, 0.11098949, -0.022394093, 0.037900597, -0.005918368]}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |[{sentence_embeddings, 0, 209, chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant, {sentence -> 0, token -> chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant, pieceId -> -1, isWordStart -> true}, [0.23909436, -0.24518585, 0.16925538, 0.03772632, 0.19876897, 0.14422661, -0.14767665, 0.091482624, 0.40534955, 0.23425461, 0.07297515, 0.20904216, 0.14991279, 0.034439836, 0.15692309, -0.22660014, 0.4984692, 0.15607512, -0.06246031, 0.18118124, -0.40332025, -0.23545621, 0.11413274, 0.03867953, -0.15152958, -0.29896826, 0.10527675, -0.38710606, -0.13991252, -0.1264247, 0.29115054, 0.4421849, -0.36225736, -0.08931695, 0.23425345, -0.1927251, -0.03938195, -0.09216583, -0.25978303, -0.090196505, -0.11270646, -0.10868349, 0.14787002, -0.082293436, -0.20846145, -0.24991119, 0.10356468, -0.2528892, -0.06511779, -0.5018126, 0.2565762, 0.2456347, 0.12197194, 0.80615383, 0.054761004, -1.1914122, 0.07345822, -0.44759268, 1.3492099, 0.25139114, -0.16827539, 0.10877169, -0.10584047, -3.173477E-5, 0.67791146, -0.051473703, 0.16415441, 0.2965118, 0.2845845, -0.18785381, -0.52876997, -0.0053867344, -0.13276136, -0.48963618, 0.24959202, 0.37735996, -0.25364423, -0.16451201, -1.1153727, -0.24465947, 0.56347054, -0.037104633, -0.26533368, -0.06813773, -1.0300778, -0.14671712, 0.3455442, -0.031133488, -0.051818006, -0.07269583, -0.31059846, 0.011011839, 0.08812031, -0.21377443, 0.123406835, 0.20032662, 0.082456745, 3.3178375E-4, 0.26566276, -0.068822004]}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |[{sentence_embeddings, 0, 1406, on  while trying to book aticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contactedand was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about theoffer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error, {sentence -> 0, token -> on  while trying to book aticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contactedand was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about theoffer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error, pieceId -> -1, isWordStart -> true}, [0.019867443, -0.104793064, 0.22376446, -0.01722627, 0.11361773, 0.01744875, -0.12983929, 0.16465235, 0.12290422, -0.041089695, 0.124493286, 0.1366714, 0.11202457, -0.02297143, 0.09542136, -0.14162742, 0.08948199, 0.083793916, -0.3351853, 0.12093975, -0.006729501, -0.044385687, 0.07553076, 0.011772893, -0.12312006, -0.16973585, -0.06004582, -0.2897935, 0.022244148, -0.035514485, 0.11465941, 0.51630837, -0.19936632, 0.05411061, 0.15672514, 0.15183216, -0.0010095105, 0.06828494, -0.11050351, -0.15427396, -0.30411556, -0.16629113, 0.08047734, -0.15354098, -0.103448845, -0.07752549, 0.03940627, -0.23045573, -0.023059856, -0.6700682, 0.35727185, 0.035275474, 0.244268, 0.6804277, -0.11570027, -1.6945853, -0.12523705, -0.19854161, 1.3979018, 0.3122782, -0.09563568, 0.26832396, -0.15231863, -0.016275486, 0.5958027, -0.19266294, 0.15365578, 0.4710298, 0.11858063, 0.017056579, -0.16575974, -0.12408217, -0.056455158, -0.43977347, 0.17618048, 0.21930413, -0.18538511, -0.08393392, -0.83069617, -0.14468251, 0.45086902, -0.09915907, -0.31851894, -0.14399838, -1.1197838, -0.17317702, 0. ...
# |[{sentence_embeddings, 0, 443, my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check numberclaim number iswith chase, {sentence -> 0, token -> my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check numberclaim number iswith chase, pieceId -> -1, isWordStart -> true}, [0.12296842, -0.08489187, 0.2092774, -0.14136894, -0.014083251, 0.04411756, -0.15363379, 0.28917402, -0.005895122, -0.11133302, 0.24499351, 0.4655112, 0.018777821, 0.054846, -0.05076474, -0.23520188, 0.23637907, 0.0032174229, -0.343225, 0.28349814, 0.14492083, -0.03654358, -0.10986748, -0.07783776, -0.04164913, -0.19265345, -0.25651228, -0.42831892, 0.10301574, -0.11902746, 0.10356798, 0.2972314, -0.069761485, 0.05066795, 0.04879808, 0.094234414, -0.045604102, 0.13086812, 0.05735135, -0.12001143, -0.11821681, -0.2524483, 0.1023872, -0.25420022, -0.0470191, -0.018439839, -0.061412778, -0.34095684, 0.0036560807, -0.72295207, 0.049001135, -0.060987372, 0.32062656, 0.68644655, -0.04050638, -1.8242842, -0.20049275, -0.09973021, 1.3655629, 0.39358404, -0.07009558, 0.2871187, -0.10774826, 0.025384031, 0.65874916, -0.13392657, 0.27013984, 0.44818673, 0.24162608, -0.0649066, -0.19957805, -0.19083148, -0.2306754, -0.44847238, 0.16000125, 0.08483876, -0.057009283, -0.15379752, -0.7993873, -0.096770465, 0.79172474, 0.0448067, -0.2213434, -0.14695048, -0.9276797, -0.18607095, -0.083221905, -0.12473249, -0.022618292, -0.13690317, -0.12934645, -0.060932036, 0.20145555, -0.19091828, -0.43593356, 0.070495054, 0.1065796, -0.042717166, 0.27330804, 0.09046223]}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, size, flatten

# Use `sentence_embeddings` as the feature column and flatten it
df_features = df_embeddings.withColumn("features", flatten(col("sentence_embeddings.embeddings")))

# Confirm that all features have the expected dimension of 100
df_features.select(size(col("features")).alias("feature_size")).groupBy("feature_size").count().show()

# Filter out any rows where the feature size is not 100
df_non_empty = df_features.filter(size(col("features")) == 100)

# Proceed with KMeans clustering
kmeans = KMeans().setK(5).setSeed(1).setFeaturesCol("features").setPredictionCol("cluster")
model = kmeans.fit(df_non_empty)
df_clustered = model.transform(df_non_empty)

# Interpret the clusters
df_clustered.groupBy("cluster", "category").count().show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+-----+
# |feature_size|count|
# +------------+-----+
# |         100|21068|
# |           0|    4|
# +------------+-----+
#
# +-------+--------------------+-----+
# |cluster|            category|count|
# +-------+--------------------+-----+
# |      3|Debt collection+O...|    2|
# |      2|Mortgage+FHA mort...|   38|
# |      0|Prepaid card+Gove...|    1|
# |      1|Consumer Loan+Ins...|    2|
# |      2|Mortgage+Home equ...|   16|
# |      4|Money transfer, v...|  172|
# |      4|Mortgage+VA mortgage|   23|
# |      3|Credit card or pr...|    5|
# |      2|Checking or savin...|    5|
# |      3|Credit reporting,...|    1|
# |      1|Money transfer, v...|    3|
# |      4|Payday loan, titl...|    3|
# |      0|Money transfer, v...|    2|
# |      4|Credit card or pr...|    5|
# |      0|Consumer Loan+Veh...|    9|
# |      1|Bank account or s...|    8|
# |      2|Money transfer, v...|   62|
# |      0|Debt collection+M...|   34|
# |      4|Consumer Loan+Paw...|    1|
# |      0|Money transfer, v...|   10|
# +-------+--------------------+-----+
# only showing top 20 rows

# %%
centers = model.clusterCenters()
wssse = df_clustered.rdd.map(
    lambda row: float(sum((row["features"][i] - centers[row["cluster"]][i]) ** 2 for i in range(len(row["features"]))))
).sum()

print("Within-Cluster Sum of Squared Errors (WSSSE) = " + str(wssse))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Within-Cluster Sum of Squared Errors (WSSSE) = 14520.128747812982

# %%
from pyspark.ml.evaluation import ClusteringEvaluator

# Initialize the ClusteringEvaluator
evaluator = ClusteringEvaluator(featuresCol="features", predictionCol="cluster", metricName="silhouette", distanceMeasure="squaredEuclidean")

# Calculate the Silhouette Score
silhouette_score = evaluator.evaluate(df_clustered)
print("Silhouette Score = " + str(silhouette_score))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Silhouette Score = 0.09824491880211028

# %%
# Interpret the clusters
df_clustered.groupBy("cluster", "category").count().show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+--------------------+-----+
# |cluster|            category|count|
# +-------+--------------------+-----+
# |      3|Debt collection+O...|    5|
# |      2|Mortgage+FHA mort...|   77|
# |      1|Consumer Loan+Ins...|   14|
# |      2|Mortgage+Home equ...|   12|
# |      3|Credit card or pr...|    4|
# |      2|Checking or savin...|    2|
# |      3|Credit reporting,...|    4|
# |      1|Money transfer, v...|   20|
# |      0|Money transfer, v...|    6|
# |      0|Consumer Loan+Veh...|   19|
# |      1|Bank account or s...|    6|
# |      2|Money transfer, v...|   81|
# |      0|Debt collection+M...|   22|
# |      0|Money transfer, v...|    9|
# |      0|Credit reporting,...|    1|
# |      3|Mortgage+FHA mort...|   73|
# |      2|Money transfer, v...|    2|
# |      2|Money transfer, v...|   22|
# |      2|Student loan+Priv...|    1|
# |      3|Money transfer, v...|    5|
# +-------+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## N-Gramas

# %% [markdown]
# # FIN
# ---
